# %%
# Import required libraries
import pandas as pd
import matplotlib.pyplot as plt

# Sample NBA data for demonstration
data = {
    'Player': ['LeBron James', 'Stephen Curry', 'Kevin Durant', 'Giannis Antetokounmpo', 'Luka Doncic'],
    'Team': ['Lakers', 'Warriors', 'Suns', 'Bucks', 'Mavericks'],
    'Points Per Game': [27.2, 29.3, 28.5, 29.9, 28.4],
    'Assists Per Game': [7.9, 6.4, 5.3, 5.8, 8.7],
    'Rebounds Per Game': [7.5, 4.5, 7.1, 11.2, 8.0]
}

# Create a DataFrame
nba_df = pd.DataFrame(data)

# Display the DataFrame
print("NBA Player Stats:")
print(nba_df)

# Plot for Points Per Game by Player
plt.figure(figsize=(10, 6))
plt.bar(nba_df['Player'], nba_df['Points Per Game'], color='skyblue')
plt.xlabel('Player')
plt.ylabel('Points Per Game')
plt.title('Points Per Game of Top NBA Players')
plt.xticks(rotation=45)
plt.show()

# Plot for Assists Per Game by Player
plt.figure(figsize=(10, 6))
plt.bar(nba_df['Player'], nba_df['Assists Per Game'], color='lightgreen')
plt.xlabel('Player')
plt.ylabel('Assists Per Game')
plt.title('Assists Per Game of Top NBA Players')
plt.xticks(rotation=45)
plt.show()

# Plot for Rebounds Per Game by Player
plt.figure(figsize=(10, 6))
plt.bar(nba_df['Player'], nba_df['Rebounds Per Game'], color='salmon')
plt.xlabel('Player')
plt.ylabel('Rebounds Per Game')
plt.title('Rebounds Per Game of Top NBA Players')
plt.xticks(rotation=45)
plt.show()
# Out:
# NBA Player Stats:
#                   Player       Team  Points Per Game  Assists Per Game  \
# 0           LeBron James     Lakers             27.2               7.9
# 1          Stephen Curry   Warriors             29.3               6.4
# 2           Kevin Durant       Suns             28.5               5.3
# 3  Giannis Antetokounmpo      Bucks             29.9               5.8
# 4            Luka Doncic  Mavericks             28.4               8.7
#
#    Rebounds Per Game
# 0                7.5
# 1                4.5
# 2                7.1
# 3               11.2
# 4                8.0

# %%
import pandas as pd

# Sample NBA player data
data = {
    'Player': ['LeBron James', 'Stephen Curry', 'Kevin Durant', 'Giannis Antetokounmpo', 'Luka Doncic'],
    'Points Per Game': [27.2, 29.3, 28.5, 29.9, 28.4],
    'Assists Per Game': [7.9, 6.4, 5.3, 5.8, 8.7],
    'Rebounds Per Game': [7.5, 4.5, 7.1, 11.2, 8.0]
}

# Create a DataFrame
nba_df = pd.DataFrame(data)

# %%
from sklearn.linear_model import LinearRegression

# Features: Assists and Rebounds
X = nba_df[['Assists Per Game', 'Rebounds Per Game']]

# Target: Points Per Game
y = nba_df['Points Per Game']

# Initialize and train the model
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Kd's stats
kevin_durant_features = [[9, 7.1]]  # Assists: 5.3, Rebounds: 7.1

# Predict Kd's Points Per Game
kevin_durant_predicted_points = model.predict(kevin_durant_features)

# Print the result
print(f"Predicted Points Per Game for Kevin Durant: {kevin_durant_predicted_points[0]:.2f}")
# Out:
# Predicted Points Per Game for Kevin Durant: 27.74
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
